# %% [markdown]
# <a href="https://colab.research.google.com/github/universeatmyfeet/DL/blob/master/Lab9/Lab9_2DCNN_J051.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import numpy as np
import requests
import cv2
import PIL.Image
import urllib
import os
import pandas as pd

# %% [markdown]
# # **Loading the data images**

# %%
stringed = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n04338517") 
print(stringed.content)
stringed_soup = BeautifulSoup(stringed.content, 'html.parser')
# Out:
# b"http://isfudo.webcindario.com/piano0.jpg\r\nhttp://www.ilovemusica.com/photos/img_2105.jpg\r\nhttp://www.ibaypro.eu/image.php?type=P&id=16739\r\nhttp://www.caterinagenta.com/decalogo/gujang.jpg\r\nhttp://images.channeladvisor.com/Sell/SSProfiles/82000025/Images/15/YMG-SB.jpg\r\nhttp://web.educastur.princast.es/cursos/imagen/archivos/cursoimagen/ORTEGA_LOPEZ_PABLO.jpg\r\nhttp://g-ecx.images-amazon.com/images/G/01/ciu/a3/03/16af820dd7a05e3d714ae010._AA280_.L.jpg\r\nhttp://www.viaurbium.com/cms/images/full/c0c7c76d30bd3dcaefc96f40275bdc0a_.jpg\r\nhttp://www.quebesistersband.com/images/drew_phelps.jpg\r\nhttp://genesis.uag.mx/edmedia/material/tmusica/images/Arpa.jpg\r\nhttp://personal.myvine.com/~leoposch/DSCN0016a.jpg\r\nhttp://www.fireballrockband.com/images/photos/gallery/288716-thumb.jpg\r\nhttp://www.hartford-hwp.com/archives/55a/176b.png\r\nhttp://i13.ebayimg.com/04/i/000/dd/8f/04eb_1.JPG\r\nhttp://www.heritageethnicmusic.com/members/607029/uploaded/strings/Cross%20Strung%20Harps.jpg\r\nhttp://www.sedaa.com/images/musical_instruments/12-string_guitar.gif\r\nhttp://www.warwickbass.com/images/Corvette-$$-NT-two-shot.jpg\r\nhttp://www.electrical-contractor.net/mt/YRBX65.jpg\r\nhttp://i5.ebayimg.com/05/i/07/ea/ca/2f_1.JPG\r\nhttp://www.liutaiomottola.com/Wing255w.JPG\r\nhttp://www.istockphoto.com/file_thumbview_approve/763104/2/istockphoto_763104_violin_scroll.jpg\r\nhttp://megh-ac.nic.in/museum/images/marynthing872.jpg\r\nhttp://www.philmultic.com/graph/instruments/ruan.jpg\r\nhttp://guitarra.artelinkado.com/gifsyfo/imagenes/Alud/Alud7.jpg\r\nhttp://www.donmack.com/Images/Misc/John2.jpg\r\nhttp://www.burger.si/MuzejiInGalerije/PokrajinskiMuzejPtuj/Glasbila/SlikaVOkvirju.JPG\r\nhttp://www.ltscotland.org.uk/nq/resources/learnlisteningonline/images/Sitar2_tcm4-371206.png\r\nhttp://static.flickr.com/2408/2426299505_0c3897e731.jpg\r\nhttp://www.nonsolomusicablog.it/immagini/electrolyre_1.jpg\r\nhttp://www.mercatinomusicale.com/allegati_small/701542.jpg\r\nhttp://albumo.com/photos2/medium/2007/12/29/17/446956.jpg\r\nhttp://static.flickr.com/190/518509509_cb8c161c9e.jpg\r\nhttp://italiano.istockphoto.com/file_thumbview_approve.php?size=1&id=2372911\r\nhttp://www.themusicboxcompany.com/images/music_related_items/Music%20Related%20Items/String%20Instruments/lPlayable%20Violin%20A8-01.jpg\r\nhttp://www.cyrguitars.com/Takamine12String003.jpg\r\nhttp://pro.corbis.com/images/42-16987805.jpg?size=572&uid=%7BC7CB6E71-3D6E-4AC0-A9F1-F63C8CF6DFFC%7D\r\nhttp://www.rayburnmusicct.com/files/strings.jpg\r\nhttp://www.istockphoto.com/file_thumbview_approve/1345388/2/istockphoto_1345388_electric_guitar_playing.jpg\r\nhttp://www.retailmontana.com/Stringed%20Instruments/3_small.jpg\r\nhttp://www.orpheon.org/OldSite/Fotos/Exhibitions/Expo-Duino/Press.jpg\r\nhttp://www.connemara.it/musica/musica/banjo%20foto/banjo%202.jpg\r\nhttp://www.musicalsinfonia.com.mx/img/inst/Cuerda.jpg\r\nhttp://www.salbaida.com/images/laud.gif\r\nhttp://z.about.com/d/goeasteurope/1/5/L/3/-/-/LatvianInstrumentKokle.jpg\r\nhttp://pro.corbis.com/images/42-17418146.jpg?size=572&uid=%7B7E600365-FD2B-4AE0-9128-AC5B89A5E545%7D\r\nhttp://www.trade-world.org/images/20185_0304DLxMAne1xsIQ.jpg\r\nhttp://www.brittensmusic.co.uk/accimages/minorc.jpg\r\nhttp://www.mercatinomusicale.com/allegati_small/843038.jpg\r\nhttp://farm1.static.flickr.com/44/139028881_8926461ffa.jpg\r\nhttp://www.trmusicals.com/instruments/small%20photo/violin1.jpg\r\nhttp://www.todomonografias.com/images/2007/02/101325.jpg\r\nhttp://farm1.static.flickr.com/140/364426401_b97a7f65d6.jpg?v=0\r\nhttp://www.pick-et-boch.com/images/photo/pm/vihuela_decoree_1.jpg\r\nhttp://62.15.226.148/fot/2006/08/06/3200718.jpg\r\nhttp://www.wydov.net/images/nova-60/dutar5.JPG\r\nhttp://i62.photobucket.com/albums/h111/matthew-groves/mandolin-bracket-ebay.jpg\r\nhttp://www.asierdbg.es/img/r/violin2/034.jpg\r\nhttp://farm1.static.flickr.com/197/490464269_accec90782.jpg?v=0\r\nhttp://www.veziana.net/images/instrument_harpe.jpg\r\nhttp://sta ...

# %%
percussion = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n03915437") 
print(percussion.content)
percussion_soup = BeautifulSoup(percussion.content, 'html.parser')
# Out:
# b'http://farm4.static.flickr.com/3135/2685021079_e515017299.jpg\r\nhttp://farm4.static.flickr.com/3248/2343731977_51aaba3d3c.jpg\r\nhttp://www.musikschule-schriesheim.de/Instrumente/bilder/percussion.jpg\r\nhttp://farm3.static.flickr.com/2317/2205457723_832bd9c27a.jpg\r\nhttp://www.classicaudio-china.com/image/cad/ICM417.jpg\r\nhttp://weniger.ch/jspielchvu/instrumente/schlag/schlag-Dateien/percussion_1.bmp\r\nhttp://static.flickr.com/1437/1452688891_0e2dfaf72a.jpg\r\nhttp://www.grahamnasby.com/misc/images_concertband/drum-set.jpg\r\nhttp://www.jents.com/instrument-gfx/lp_black_conga_set.jpg\r\nhttp://farm1.static.flickr.com/144/359237668_593d5e6585.jpg\r\nhttp://farm1.static.flickr.com/51/211022663_8942de472d.jpg\r\nhttp://musambara.de/bilder/djembe.jpg\r\nhttp://bp1.blogger.com/_94qFQqFbZyc/SCPEQTvLqaI/AAAAAAAAAI4/6jaBCtVs-TU/s400/guiro.jpg\r\nhttp://i38.photobucket.com/albums/e120/celticangels/caroline20corr205.jpg\r\nhttp://www.sikhmusicalheritage.com/images/instruments/drums.jpg\r\nhttp://www.tabla.com/articles/Image41.gif\r\nhttp://farm2.static.flickr.com/1187/1452757723_50d2b91fcb.jpg\r\nhttp://farm3.static.flickr.com/2233/2377730212_975d48991c.jpg\r\nhttp://www.corneroak.com/images/instruments/drums_lg.jpg\r\nhttp://farm4.static.flickr.com/3142/2323337394_214d18b2c1.jpg\r\nhttp://isfudo.webcindario.com/maracas0.jpg\r\nhttp://www.jamlandstudio.com/images/DSC_0004a.jpg\r\nhttp://www.flash-connection.de/bilder/instrumente.jpg\r\nhttp://www.caulfieldmusic.com.au/graphics/products/DrumDjembeRungo.jpg\r\nhttp://www.themusichouse.com/musich/images/instr/perc/lp.jpg\r\nhttp://farm1.static.flickr.com/225/485987032_e67fdcecfe.jpg\r\nhttp://bp1.blogger.com/_L9VbxKU4g7k/Rkb9Bsz_1dI/AAAAAAAAA9g/FVg8Jdq10bw/s400/tabla.jpg\r\nhttp://farm3.static.flickr.com/2253/2446247901_f847c46aaa.jpg\r\nhttp://farm4.static.flickr.com/3122/2449630954_732de892da.jpg\r\nhttp://static.flickr.com/195/507053564_4ce5fb578e.jpg\r\nhttp://farm4.static.flickr.com/3215/2300338726_40b37e8f2c.jpg\r\nhttp://farm1.static.flickr.com/232/478418600_b715265873.jpg\r\nhttp://www.grahamnasby.com/misc/images_concertband/tympani5.gif\r\nhttp://saol.mine.nu/alboka/instrumentos/djembe2.jpg\r\nhttp://images.andale.com/f2/121/104/7752950/2006/11/17/Instruments220.jpg\r\nhttp://image.askyaya.com/autoupdate/3669/2379.jpg\r\nhttp://i2.ebayimg.com/02/i/000/e8/80/2b6a_2.JPG\r\nhttp://www.musicalnirvana.com/instruments/pakhawaj.jpg\r\nhttp://farm1.static.flickr.com/2/1697724_7db3d18284.jpg\r\nhttp://farm2.static.flickr.com/1354/1350717963_7b01b57c34.jpg\r\nhttp://static.flickr.com/3230/2343726221_f45d361553.jpg\r\nhttp://www.musambara.de/bilder/percussion.jpg\r\nhttp://imgsrc.baidu.com/baike/pic/item/2cb4fefeddf0fc225d60084d.jpg\r\nhttp://www.artisanat-africain.com/instruments/photos_instruments/congas_017_550.jpg\r\nhttp://farm2.static.flickr.com/1158/781604622_d50fb9df7d.jpg\r\nhttp://www.96art.com/UserDocument/yongxin/Picture/20070205203441.jpg\r\nhttp://www.parainmigrantes.info/wp-content/uploads/2007/12/batucada-de-integrarte-3.jpg\r\nhttp://farm3.static.flickr.com/2192/1504147881_484f7d5031.jpg\r\nhttp://imageserver.5maiya.com/comshop/products/170_365112.jpg\r\nhttp://farm1.static.flickr.com/157/416006124_64c06c9de3.jpg\r\nhttp://farm4.static.flickr.com/3177/2520579908_59d3195433.jpg\r\nhttp://farm2.static.flickr.com/1131/1453511867_8adceb4c1b.jpg\r\nhttp://ecx.images-amazon.com/images/I/41JRNNwfFBL.jpg\r\nhttp://www.metalwax.com/Images/cymbal46.jpg\r\nhttp://static.flickr.com/3081/2281693737_b388c27807.jpg\r\nhttp://www.duende-music.co.uk/images/bombo.jpg\r\nhttp://www.poongmul.com/poongmul/images/instrument_bhuk.jpg\r\nhttp://farm3.static.flickr.com/2134/1693386566_5a64608366_o.jpg\r\nhttp://farm1.static.flickr.com/9/13357236_4e1bb6398c.jpg\r\nhttp://farm2.static.flickr.com/1179/1453558660_93a5d766f8.jpg\r\nhttp://www.batraenterprises.com/pcat-gifs/products-small/Percussion.jpg\r\nhttp://www.industrialpercussion.com/industrial_percussion_web_page_022405008004.jpg\r\nhttp:/ ...

# %%
wind = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n04586932") 
print(wind.content)
wind_soup = BeautifulSoup(wind.content, 'html.parser')
# Out:
# b'http://farm1.static.flickr.com/141/361514000_ba10cc390b.jpg?v=0\r\nhttp://www.tulumba.com/mmTULUMBA/Images/HO100011XA002_250.jpg\r\nhttp://imgsrc.baidu.com/baike/abpic/item/7a8a1446f89b9b1a6b63e5bc.jpg\r\nhttp://static.flickr.com/2266/2434819619_375d690cfd.jpg\r\nhttp://www.artists-india.com/i/shailesh_bhagwat.jpg\r\nhttp://hk.geocities.com/blcwcband/intru_pic/horn.gif\r\nhttp://www.balkanfolk.com/pic/shop-products/thumb3/530-bulgarian-kaba-gaida-bagpipe.jpg\r\nhttp://comemusic.com/icon/book/instrument/jpg/saxophone.jpg\r\nhttp://yzjade.com/skyway/images/4005.gif\r\nhttp://www.windblowers.com/images/news/1-25-AKAI-EWI-4000s.jpg\r\nhttp://www.daviddalesio.it/page1/images/curriculum_html_5d3b9de0.jpg\r\nhttp://www.mercadolibre.cl/jm/img?s=MLC&f=5894107_6624.jpg&v=P\r\nhttp://www.brassreview.com/reviews/data/147/1brasswind_490L.jpg\r\nhttp://aero.ofps.edu.hk/%7Ecyberfair/music/images/wind_e.jpg\r\nhttp://www.xmusicpro.com/product_images/334_medium.jpg\r\nhttp://impactinit.assetsdelivery.com/compings/prometeus/prometeus0704/prometeus070400236.jpg\r\nhttp://static.flickr.com/1085/527900014_e84f2032ce.jpg\r\nhttp://www.yamaha-europe.com/picture_archiv/products/10_Musical_instruments/Orchestra/brass_instruments/trombones/ybl421g_low_jpg.jpg\r\nhttp://wwwdelivery.superstock.com/Image/1366/Thumb/1366R-166.jpg\r\nhttp://lh3.ggpht.com/_ARLWt2Mlej8/R8LQFLGwSNI/AAAAAAAAAJ0/bT_HBI2URQg/j0399890.jpg\r\nhttp://web.tiscali.it/asscultmia/mike.JPG\r\nhttp://www.istockphoto.com/file_thumbview_approve/5513624/2/istockphoto_5513624_alto_sax_pearl_keys.jpg\r\nhttp://www.thugsatbay.com/tab/files/violin-296_400x300.jpg\r\nhttp://pics.novica.com/pictures/10/p110650_1.jpg\r\nhttp://static.flickr.com/2137/1537515615_0b7e686482.jpg\r\nhttp://www.photostock.de/img/prev/ps-34115.jpg\r\nhttp://chipchick.com/wp-content/uploads/2007/03/ewiusb.jpg\r\nhttp://www.tornadobigband.com/images/bigband08_002.jpg\r\nhttp://www.perutravels.net/peru-pictures/music-zampona.jpg\r\nhttp://comemusic.com/icon/book/instrument/jpg/cornet.jpg\r\nhttp://images.dangdang.com/images/20142676_s.jpg\r\nhttp://www.sweetwater.com/images/items/215/WorldWindA.jpg\r\nhttp://blog.makezine.com/multiwind1.jpg\r\nhttp://chsmusic.instrumental.googlepages.com/wind-musical-instruments.gif/wind-musical-instruments-full.jpg\r\nhttp://www.bajaao.com/images/Jupiter/jas565gl.jpg\r\nhttp://img.yeedou.com/images/01-20070706-019-1275019-1594833-200_200.jpg\r\nhttp://www.paulnoll.com/China/Music/mus-Souna-ours.jpg\r\nhttp://www.klinemusic.com/Woodwind%20Case.jpg\r\nhttp://visual.merriam-webster.com/images/arts-architecture/music/wind-instruments_2.jpg\r\nhttp://www.singhmusic.com/WindInstruments/images/sec_thumb_OI-21.jpg\r\nhttp://www.communigate.co.uk/hants/belgarummusic/phpNaqWS6\r\nhttp://static.flickr.com/2150/2149241277_48496796b8.jpg\r\nhttp://www.magictails.com/abydos/images/mid-east/wind/cane_flute_ff.jpg\r\nhttp://www.metronimo.com/uk/games/quiz/images/clarinette.GIF\r\nhttp://www.magictails.com/abydos/images/mid-east/wind/cane_whistle_b.jpg\r\nhttp://digilander.libero.it/delmontecarlo/Clarinetto.jpg\r\nhttp://idolator.com/assets/resources/2007/10/recorder.jpg\r\nhttp://nativedrums.ca/media/circle/imgs/200/flutes.willow.jpg\r\nhttp://www.kidzworld.com/img/upload/article/a585i1_recordersGROUPAw.jpg\r\nhttp://www.kalipedia.com/kalipediamedia/artes/media/200708/22/musica/20070822klpartmsc_8.Ees.SCO.png\r\nhttp://www.usashopcn.com/uploadpic/2006082816465674805.jpg\r\nhttp://www.zecchinimusica.it/data/images/thumbnail/P00775_01_JF_ANDREWS_FLAUTO_TRAVERSO.jpg\r\nhttp://img.cn.china.cn/image/10/20/86/00/95/1020860228_1_big.jpg\r\nhttp://www.saundrecs.co.uk/images/praet_01.jpg\r\nhttp://cybermusicalinstruments.com/images/products/TSTS-670E.jpg\r\nhttp://www.istockphoto.com/file_thumbview_approve/3963854/2/istockphoto_3963854_clarinet_mouth_piece.jpg\r\nhttp://www.e-classical.com.tw/prtfamily/program/jazz_club/images/123.jpg\r\nhttp://www.davescheapmusicalinstruments.com/i/130px-Tenorsaxophon.jpg\r\nhtt ...

# %%
keyboard = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n03614532") 
print(keyboard.content)
keyboard_soup = BeautifulSoup(keyboard.content, 'html.parser')
# Out:
# b"http://www.dreiklangev.de/graphics/titel--musikinstrumente-keyboard.jpg\r\nhttp://static.flickr.com/56/159589507_634a6f7465.jpg\r\nhttp://www.gobizkorea.com/att/cat/royale/tp_html/img/royale_cat_5_small_img_2.jpg\r\nhttp://farm2.static.flickr.com/1143/1227131938_1c5fb832f0.jpg\r\nhttp://musicbookworld.com/hammond_keys.jpg\r\nhttp://farm1.static.flickr.com/49/117901127_00a6aeeb74.jpg\r\nhttp://www.crescendomusic.com.au/uploaded/images/client_added/Keyboards/At_keyboard.jpg\r\nhttp://images.jupiterimages.com/common/detail/82/77/23297782.jpg\r\nhttp://sklep.all4m.com/catalog/images/PSRE403.jpg\r\nhttp://farm1.static.flickr.com/164/438881364_4f0773d59c.jpg\r\nhttp://www.speedmusic.co.uk/acatalog/E203jpg.jpg\r\nhttp://farm3.static.flickr.com/2156/1508713470_1f2249e4e6.jpg\r\nhttp://farm2.static.flickr.com/1125/531966924_c5060ae57e.jpg\r\nhttp://www.rhodeschroma.com/content/promo/unleashed.jpg\r\nhttp://www.fargelanda.se/CMImageLibrary/10087_273_800_keyboard.jpg\r\nhttp://www.musictag.co.uk/images/dict/piano-grand.jpg\r\nhttp://farm1.static.flickr.com/194/458399706_4b5e05a9b9.jpg\r\nhttp://www.chinawholesalegift.com/pic/Toy-Gifts/Keyboard-Musical-Instument/ELECTRONIC-KEYBOARD-2151349631.jpg\r\nhttp://farm3.static.flickr.com/2050/2129079930_8ef4c40623.jpg\r\nhttp://www.nicholasgood.net/images/harp_opus_17_01.jpg\r\nhttp://www.hiddentrailmedia.com/images/keyboard_a.gif\r\nhttp://static.flickr.com/64/202593122_d972eb8324.jpg\r\nhttp://www.allaboutbutterflies.com/kgifs/Keyboardpiano.GIF\r\nhttp://www.thesecretsout.net/productPics/CA11000388M_Keyboard.jpg\r\nhttp://thedeepelement.com/trashaudio/landau2.jpg\r\nhttp://www.metromusic.net.au/images/dsc01021.jpg\r\nhttp://www.cdu.edu.au/cym/images/02keyboard.jpg\r\nhttp://farm4.static.flickr.com/3089/2609106357_03f4eb5d3e.jpg\r\nhttp://farm1.static.flickr.com/46/168978640_fdf2e1d6f8.jpg\r\nhttp://content.answers.com/main/content/wp/en/thumb/e/e1/180px-Piano_keyboard.JPG\r\nhttp://static.flickr.com/1298/1041841186_b5b2443604.jpg\r\nhttp://www.keyboardart.com/art/instruments.jpg\r\nhttp://www.alte-tasteninstrumente.de/bilder/instrumente/tafelklaviere/tfk05004c.jpg\r\nhttp://static.flickr.com/3048/2566520696_4b556c3096.jpg\r\nhttp://media.zzounds.com/media/feed/large/CASPX555.jpg\r\nhttp://www.musikhaus-ferber.de/img/keybord.gif\r\nhttp://farm3.static.flickr.com/2253/2043964721_303752ae8d.jpg\r\nhttp://farm3.static.flickr.com/2154/1600058414_4e6a52c815.jpg\r\nhttp://www.musicinstrument.biz/images/pic_yamaha_ps120.jpg\r\nhttp://images.taiwan.ru/img/62204/piano--1.jpg\r\nhttp://farm1.static.flickr.com/41/124518195_e78e901aa7.jpg\r\nhttp://www.laorejadigital.com/productos/articulos/a355/b4keyboard_xx.jpg\r\nhttp://farm1.static.flickr.com/104/262006673_fc6cbd95af.jpg\r\nhttp://static.flickr.com/201/446730279_6426d89cb3.jpg\r\nhttp://www.musiciansbuy.com/mmMBCOM/images/YAMAHA_psrs900.jpg\r\nhttp://farm3.static.flickr.com/2383/2127155920_23a14a73b7.jpg\r\nhttp://farm1.static.flickr.com/159/438973675_4122d13327.jpg\r\nhttp://farm1.static.flickr.com/50/141743294_56ea064945.jpg\r\nhttp://farm1.static.flickr.com/95/282460792_1d806c48c4.jpg\r\nhttp://www.mastermusiconline.com/nagma/harmonium-orginal.jpg\r\nhttp://farm1.static.flickr.com/204/481037488_9a0571021e.jpg\r\nhttp://farm1.static.flickr.com/49/137761891_51afa9a553.jpg\r\nhttp://farm1.static.flickr.com/31/87978699_147166e13c.jpg\r\nhttp://www.davejford.co.uk/Images/musical/instruments/Keys/Intervals/PianoOctave.gif\r\nhttp://static.flickr.com/237/461896479_403a09e7d3.jpg\r\nhttp://www.sweetwater.com/publications/sweetnotes/sn-earlysummer2000/graphics/xv-88.jpg\r\nhttp://www.monalisa-twins.com/image-files/keyboard.jpg\r\nhttp://farm3.static.flickr.com/2341/2212814614_dcffcc36ac.jpg\r\nhttp://www.harpsichord-holland.nl/Taskin/Taskin_decoration_350kb.jpg\r\nhttp://cachepe.zzounds.com/media/quality,85/brand,zzounds/fit,400by400/p5335h-af86a04b6f5f01f31ed851c3acd66819.jpg\r\nhttp://farm1.static.flickr.com/206/510379431_f23d4e902b.jpg\r\nhttp://farm1.st ...

# %%
bass = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n02803349")  
print(bass.content)
bass_soup = BeautifulSoup(bass.content, 'html.parser')
# Out:
# b"http://farm4.static.flickr.com/3284/2659585644_cfb000877a.jpg\r\nhttp://img180.imageshack.us/img180/8352/bass013uz8.jpg\r\nhttp://www.montfoortjazz.nl/toppage2_files/image006.jpg\r\nhttp://farm1.static.flickr.com/25/89138899_cb0c2f6077.jpg\r\nhttp://i250.photobucket.com/albums/gg244/CenterpieceJazz/11_13_7---Double-Bass_web.jpg\r\nhttp://www.cathowenpoet.150m.com/instruments04.jpg\r\nhttp://farm3.static.flickr.com/2112/2110264342_3a7de079ee.jpg\r\nhttp://www.musikhaushorn.de/ibanez-iceman.jpg\r\nhttp://z.about.com/d/musiced/1/0/a/2/doublebass2.jpg\r\nhttp://www.alexanderphotoimaging.com/Product_Images/Bootsy_Bass.jpg\r\nhttp://farm1.static.flickr.com/128/413002009_e87f7ae326.jpg\r\nhttp://www.desertcruising.com/images/ebass.jpg\r\nhttp://www.warwickbass.com/images/Corvette-$$-NT-two-shot.jpg\r\nhttp://i5.ebayimg.com/07/i/000/fb/51/da7b_1.JPG?set_id=7\r\nhttp://farm2.static.flickr.com/1147/697728600_1fce92e7b9.jpg\r\nhttp://farm1.static.flickr.com/178/487378983_b4c8102135.jpg\r\nhttp://farm3.static.flickr.com/2269/1890853268_1b05113916.jpg\r\nhttp://meatexz.com/cheesyguitars/tonika_bass/i-1.jpg\r\nhttp://www.orchestergraben.de/images/instruments/doublebass.jpg\r\nhttp://jessejoe.com/images/bass.jpg\r\nhttp://www.vittoriopepe.com/images/bass1.jpg\r\nhttp://graciaguitar.com.ar/fotos/bajo%20jazzbass%20caja%20costado.jpg\r\nhttp://www.customguitars.com/images/quilted-maple-bass.jpg\r\nhttp://farm4.static.flickr.com/3123/2692391307_78cd2d0e9e.jpg\r\nhttp://onceeternalmedia.com/bass0.jpg\r\nhttp://www.japan-musical-instruments.com/images/02woodline.jpg\r\nhttp://farm3.static.flickr.com/2062/2197074218_5ef518b953.jpg\r\nhttp://cachepe.samedaymusic.com/media/quality,85/brand,sameday/GrindBass5NTB_00462600-fc61d35a9123cc131c31382d720e07de.jpg\r\nhttp://farm1.static.flickr.com/188/477480877_aa9c482ea3.jpg\r\nhttp://farm1.static.flickr.com/138/353188373_8670dc8f38.jpg\r\nhttp://farm3.static.flickr.com/2367/2228925210_05a104715f.jpg\r\nhttp://farm2.static.flickr.com/1095/869000955_5e90d33f18.jpg\r\nhttp://www.dkimages.com/discover/previews/931/684729.JPG\r\nhttp://www.marleaux-bass.com/eng/bilder/bass_braun.jpg\r\nhttp://farm2.static.flickr.com/1218/535075219_b17e71a591.jpg\r\nhttp://farm1.static.flickr.com/28/42969656_ac77701d52.jpg\r\nhttp://nitetymesounds.com/louonline/jslmusic/images/ibanez_sr406_bass.jpg\r\nhttp://www.musicyo.com/product_images/534_hero.jpg\r\nhttp://farm4.static.flickr.com/3164/2332569122_cebc9a6801.jpg\r\nhttp://www.ss-gig.com/bass/Fender%20'72%20Mustang%20Bass.jpg\r\nhttp://www.8thstreet.com/images/washburn-ab10.jpg\r\nhttp://farm1.static.flickr.com/75/224586964_046e8ee54d.jpg\r\nhttp://farm3.static.flickr.com/2071/2138103650_7ca1e48306.jpg?v=0\r\nhttp://farm2.static.flickr.com/1292/730845464_c1ccb2b980.jpg\r\nhttp://farm4.static.flickr.com/3139/2283087878_c94ca21f53.jpg\r\nhttp://ecx.images-amazon.com/images/I/51YQYPYH0XL._SL500_AA280_.jpg\r\nhttp://static.flickr.com/2136/1542103128_a943709791.jpg\r\nhttp://farm4.static.flickr.com/3076/2455425675_9e6e2cd941.jpg\r\nhttp://upload.wikimedia.org/wikipedia/commons/6/6a/Double_bass_C_extension.jpg\r\nhttp://www.marleaux-bass.com/eng/bilder/jazzbass_rot.jpg\r\nhttp://www.johandenblanken.nl/Basgitaar%20History_bestanden/contrabas.gif\r\nhttp://www.folkytowers.be/afbeeldingen/gt+moore+06.jpg\r\nhttp://farm4.static.flickr.com/3019/2450950734_1db9b6d028.jpg\r\nhttp://www.morayfieldmusic.com/Products/Guitarbass/JD/JD200.jpg\r\nhttp://farm3.static.flickr.com/2031/2412067413_839c00907e.jpg\r\nhttp://www.musiccenter-magdeburg.de/images/medium/american_deluxe_precision_bass_rw_chrome_silver.jpg\r\nhttp://www.motorheadbangers.de/LemmyBassBackstage.jpg\r\nhttp://central-music.net/images/DSC00371.JPG\r\nhttp://farm1.static.flickr.com/180/401593162_c8b84b7706.jpg\r\nhttp://ecx.images-amazon.com/images/I/31LLOgN2hpL._SL500_AA280_.jpg\r\nhttp://farm3.static.flickr.com/2323/2256578314_7317feb704.jpg\r\nhttp://farm1.static.flickr.com/164/438092406_7afb1f75d2.jpg\r\nhttp://www.larkstree ...

# %%
barrel = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n02795978") 
print(barrel.content)
barrel_soup = BeautifulSoup(barrel.content, 'html.parser')
# Out:
# b"http://farm1.static.flickr.com/27/40244128_1e0d156caa.jpg\r\nhttp://www.maesto.com/Resources/bacigalupo-45ger.jpeg\r\nhttp://www.themusicboxshop.co.uk/image/bo5.jpg\r\nhttp://www.alanpell.com/Mini-20/Mini-20%20veneered6(grey%20background).jpg\r\nhttp://www.allroundfeestmuziek.nl/images/jerry-draaiorgel.jpg\r\nhttp://egrefin.free.fr/images/Chamberlin/M200/M200.jpg\r\nhttp://farm1.static.flickr.com/157/422340900_b88e7256d0.jpg?v=0\r\nhttp://www.worldclassluxuries.com/images/organ_a.jpg\r\nhttp://farm1.static.flickr.com/74/226986004_0e95a0cbaa.jpg\r\nhttp://www.amica.org/Live/Gallery/LadyLiberyOrganGrind/100_3515_small.jpg\r\nhttp://www.mobilipoletto.com/public/2particolari/organetto-3.jpg\r\nhttp://www.the2jacks.com/scotland/organ-grinder.jpg\r\nhttp://static.marktnet.nl/adimg/200710/1077001-8528-300x383-f.jpg\r\nhttp://www.leaderplus.nl/nederlands/gebieden/beerze-reusel/images/draaiorgel.jpg\r\nhttp://www.sterentertainment.nl/orgel.jpg\r\nhttp://www.vandornsclockshop.com/images/band_organ.gif\r\nhttp://fotos.marktplaats.nl/kopen/2/26/hCPHjKnasDNAKoHBUuQ1tw==.jpg\r\nhttp://farm1.static.flickr.com/17/23012078_7b61d550fe.jpg\r\nhttp://farm1.static.flickr.com/237/526441660_0cf40477ba.jpg\r\nhttp://farm4.static.flickr.com/3295/2664022485_c2a0fc067b.jpg\r\nhttp://farm4.static.flickr.com/3042/2453854792_815c892ff3.jpg\r\nhttp://farm4.static.flickr.com/3228/2387634631_ef49e51f90.jpg\r\nhttp://upload.wikimedia.org/wikipedia/commons/thumb/d/de/Lunder_kirke_orgel_020.jpg/796px-Lunder_kirke_orgel_020.jpg\r\nhttp://thumb17.webshots.net/s/thumb3/6/54/35/14265435sWNLexThJQ_th.jpg\r\nhttp://kenlovern.com/images/handsonorgan.jpg\r\nhttp://organstudio.co.uk/digital-organs/images/products/54_small.jpeg\r\nhttp://upload.wikimedia.org/wikipedia/commons/thumb/c/c5/Draaiorgel_De_Koning.jpg/800px-Draaiorgel_De_Koning.jpg\r\nhttp://tkfiles.storage.msn.com/x1pbglk-vqL4BvDFQqCxgiEoPS1_FmtF6niucVUJa-t4Da_ZEDpZLKclkptACsnbXCxFKq_wr4HaPCWMlNf4_nhBpWkdTmoQh8k-OwWgePgwX9Geno-TmqxGP6ZylgI6ifc5dq_M7ihOHBvkpCTo6o-uw\r\nhttp://www.mainemaritimemuseum.org/uploads/rich_text_editor/22organ.JPG\r\nhttp://www.advancedwarning.nl/lonnievoet.jpg\r\nhttp://farm4.static.flickr.com/3148/2735280147_7acc463a71.jpg\r\nhttp://www.museumoflondon.org.uk/archive/exhibits/urbanGrime/images/ug_objects_barrelorgan_large.jpg\r\nhttp://www.pagreatlakes.com/adventure/image/45/1920_wurlitzer_military_band_organ-thumb.bmp?1171311605\r\nhttp://www.leludion.com/Imag_barbarie/27Turner.JPG\r\nhttp://farm1.static.flickr.com/103/253531926_3c84c2be5e.jpg\r\nhttp://img517.imageshack.us/img517/1478/070729asbeek44ip6.jpg\r\nhttp://www.pigwont.net/wp-content/uploads/2007/09/birthdayskasselmonks-069.jpg\r\nhttp://www.pianobench.com/images/cat/organ.jpg\r\nhttp://farm1.static.flickr.com/44/153717712_8bb71f99c6.jpg\r\nhttp://www.carousels.com/photoalbum/0103-2.jpg\r\nhttp://www.organstop.com/images/bishsig.jpg\r\nhttp://www.homegrownmusic.net/files/imagecache/artistimage_main/files/band_photos/bujak.jpg\r\nhttp://www.leludion.com/Imag_barbarie/32pri_bien.gif\r\nhttp://www.worldclassluxuries.com/images/organ.jpg\r\nhttp://static.flickr.com/17/21067803_597f1b7a83.jpg\r\nhttp://farm3.static.flickr.com/2202/2178517464_02e2823589.jpg\r\nhttp://farm1.static.flickr.com/105/313240207_5a918ed41c.jpg\r\nhttp://farm1.static.flickr.com/38/78661822_250070bbfd.jpg\r\nhttp://upload.wikimedia.org/wikipedia/commons/1/16/Justinuskirche_Orgel_Tastatur.jpg\r\nhttp://farm1.static.flickr.com/47/108254646_8036423ac3.jpg\r\nhttp://infao5501.ag5.mpi-sb.mpg.de:8080/Wikipedia-Lip6-MM/images/1129692\r\nhttp://auction-team.de/new_highlights/2002_05/oa/437.jpg\r\nhttp://farm4.static.flickr.com/3199/2684627373_65fc595fee.jpg\r\nhttp://www.berliner-drehorgel.de/Viololinopan_20_Standard4.jpg\r\nhttp://www.harpkit.com/Merchant2/graphics/shoppingcart/hurdfinm_th.jpg\r\nhttp://www.istockphoto.com/file_thumbview_approve/100410/2/istockphoto_100410_playing_the_hurdy_gurdy.jpg\r\nhttp://www.antikfuehrer.de/glapa.de/kannel.jpg\r\nhttp://fa ...

# %%
jews = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n03597916")  
print(jews.content)
jews_soup = BeautifulSoup(jews.content, 'html.parser')
# Out:
# b"http://www.sudeepaudio.com/folk/imgs/murchang.gif\r\nhttp://www.fotosearch.com/bthumb/phd/PHD144/os34021.jpg\r\nhttp://www.mouthmusic.com/images/HORZCOL3.JPG\r\nhttp://www.didgebits.com/files/distributor_product_bits/AJewsHarp.jpg\r\nhttp://www.jewsharpguild.org/images/Trophy_1stnote.jpg\r\nhttp://minimmusic.co.uk/images/JAWS_HARP2.jpg\r\nhttp://www.arikah.com/encyclopedia/images/7/79/JewsHarpCivilWar.jpg\r\nhttp://farm1.static.flickr.com/190/496599371_ea10f20abb.jpg?v=0\r\nhttp://static.flickr.com/183/428003126_8ffdb982cb.jpg\r\nhttp://www.buona-vista.com/pic-labo/limg/5-3-5.jpg\r\nhttp://static.flickr.com/113/291306256_f8e0be6e9e.jpg\r\nhttp://blog90.fc2.com/a/ayeyai/file/jews-harp.jpg\r\nhttp://khomus.ru/photos/gotov1_ic.jpg\r\nhttp://es.woodbrass.com/images/woodbrass/guimbarde.jpg\r\nhttp://farm1.static.flickr.com/187/386964067_50055b78bb.jpg\r\nhttp://static.flickr.com/159/433423105_80f40faf99.jpg\r\nhttp://www.koizumigakki.com/02item/04-koukin/001/koukin001.jpg\r\nhttp://www.khomus.de/images/20021126_GEA%20-%20Werner%20Kumpl_5sm.jpg\r\nhttp://www.vargan.ru/vargan/img_for_union/master_valery.jpg\r\nhttp://www.jewsharper.info/images/31.jpg\r\nhttp://vargan.ru/vargan/img_for_special/potkin-002.jpg\r\nhttp://aspiration.free.fr/guimbarde/guimbarde-site/hun5.jpg\r\nhttp://dziansenaro.narod.ru/kontcertn2.jpg\r\nhttp://static.flickr.com/80/216771783_019be9e53d.jpg\r\nhttp://www.kaypacha.com.ar/instrumentos/arpa/marransano-mano.jpg\r\nhttp://farm1.static.flickr.com/144/398017958_83f1f65794.jpg\r\nhttp://spiritdimension.com/magical-music/imgvarg/varganlg.jpg\r\nhttp://thumbs.dreamstime.com/thumb_113/1168982368dwAqMM.jpg\r\nhttp://www.khomus.de/images/kathmandusm.jpg\r\nhttp://i192.photobucket.com/albums/z217/Masinai/USA55blauw.jpg\r\nhttp://www.mouthmusic.com/images/wimmer1.jpg\r\nhttp://www.historylives.com/music_files/mouthharp2.jpg\r\nhttp://spiritdimension.com/magical-music/imgvarg/varganist3.gif\r\nhttp://hi-spam.up.seesaa.net/MP3/nep10.jpg\r\nhttp://www.kaypacha.com.ar/instrumentos/arpa/marransano-toque2-ch.jpg\r\nhttp://www.szilagyi-jewsharp.com/apocalys.jpg\r\nhttp://www.jewsharpguild.org/jhgpa/Balkan_Mong-jh2a_small.jpg\r\nhttp://vargan.ru/vargan/img_for_special/varganchay07.jpg\r\nhttp://farm4.static.flickr.com/3166/2563899688_3188540e1b.jpg?v=0\r\nhttp://i4.ebayimg.com/06/i/000/dd/7e/90db_2.JPG\r\nhttp://www.namaste-production.com/naviulm6.jpg\r\nhttp://www.vargan.ru/vargan/img_for_special/orozobay02.jpg\r\nhttp://www.antropodium.nl/potkin5,5blauwgroen.jpg\r\nhttp://www.vargan.ru/vargan/img_for_vse/rahimov_4.jpg\r\nhttp://myweb.tiscali.co.uk/ye1606gfrowley/Jews%20Harp%20triple.jpg\r\nhttp://www.mouthmusic.com/images/Horzing-Coal-Black-A--How-t_(Small).jpg\r\nhttp://bp1.blogger.com/_0CPq8aAV7-A/RlIVocu4RGI/AAAAAAAAADo/ruaeFs-BaMY/s400/Peace_harp.jpg\r\nhttp://www.fretnfiddle.com/joe/images/pierre-c.jpg\r\nhttp://www.pick-et-boch.com/images/photo/pm/guimbarde_nepalaise_forme_t_001.jpg\r\nhttp://thumbs3.ebaystatic.com/pict/1502464476268080_1.jpg\r\nhttp://static.flickr.com/168/413436653_b5e7d97c88.jpg\r\nhttp://www.istockphoto.com/file_thumbview_approve/3835188/2/istockphoto_3835188_mouth_harp.jpg\r\nhttp://www.raggedsoldier.com/pictures/toycluster/jaw_harp_sm.jpg\r\nhttp://www.fairfax.org.uk/main/gallery/gallery5/images/games.jpg\r\nhttp://www.elderly.com/images/tiny/new_instruments/200N/JH1.jpg\r\nhttp://farm1.static.flickr.com/163/402598992_8a93a03770.jpg\r\nhttp://ecx.images-amazon.com/images/I/21fX83cJLhL._SL160_AA160_.jpg\r\nhttp://img.encuentraprecios.com/prd/157/4760028.jpg\r\nhttp://www.volny.cz/weytora/nastroje/grumle.jpg\r\nhttp://www.jewsharp.com/images/GORDON1.JPG\r\nhttp://www.binaswar.com/Morchang1.jpg\r\nhttp://thumbs2.ebaystatic.com/pict/120258482059_1.jpg\r\nhttp://aspiration.free.fr/guimbarde/guimbarde-site/hun1.jpg\r\nhttp://lostandfoundrelics.com/mics%20items%20021.jpg\r\nhttp://www.aakashjain.com/old+site/indian-music/images/Murchang.jpg\r\nhttp://www.kaypacha.com.ar/instrumentos/arpa/marransano-ch. ...

# %%
music = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n03801353")  
print(music.content)
music_soup = BeautifulSoup(music.content, 'html.parser')
# Out:
# b'http://www.tusciaromana.info/files-redazione/Carillon-302x302.gif\r\nhttp://www.plowandhearth.com/plow_assets/images/shop/catalog/80215.jpg\r\nhttp://www.umassmag.com/2007/Winter2007/img_content/grenier7.jpg\r\nhttp://www.antiquehelper.com/auctionimages/25933t.jpg\r\nhttp://www.shop4musicboxes.co.uk/ekmps/shops/deanorgans/images/mjb41_open.jpg\r\nhttp://etailelectronics.com/Merchant2/graphics/00000001/9359tn.jpg\r\nhttp://ring.managerjeans.com/p/91/images/prima-ballerina-musical-jewelry-box987755.jpg\r\nhttp://static.flickr.com/1136/898875723_2bfa993e13.jpg\r\nhttp://www.tias.com/stores/gea/pictures/music598c.jpg\r\nhttp://www.arnovanderheijden.nl/winkel/plaatje_klein_polyphon-4.jpg\r\nhttp://www.mercadolibre.com.ar/jm/img?s=MLA&f=33462379_1474.jpg&v=P\r\nhttp://www.2ndeal.com/images/100/caja-de-musica-joyero-bailarina---1.jpg\r\nhttp://farm1.static.flickr.com/28/96480639_793056461d.jpg\r\nhttp://www.kingsrivergifts.com/store/images/cr216sm.jpg\r\nhttp://www.giftgem.com/prodimages/28056.jpg\r\nhttp://www.clocksandmusicboxes.com/photos/baroque2.jpg\r\nhttp://mrxmaspics.homestead.com/files/23914.JPG\r\nhttp://boxhappyblog.typepad.com/photos/uncategorized/2008/02/25/fairy_musical_box.jpg\r\nhttp://farm1.static.flickr.com/61/211557202_a04c577ca7.jpg\r\nhttp://farm4.static.flickr.com/3056/2613743215_952eba7a76.jpg\r\nhttp://www.lechatnoirboutique.com/prodimages/Snowbabies%20-%20Music%20Box%20-%20Dont%20Fall%20Down-sm.jpg\r\nhttp://www.giftsonline.net/catalog/images/birds_multiple_music_box.jpg\r\nhttp://www.bennettauctions.com/2005/121305_portsmouth/spare6/Music-box.jpg\r\nhttp://www.serenitycentre.yk.ca/Musical%20piano%20jewelry%20box.jpg\r\nhttp://www.favoritejewelry.com/RingBoxes/CarouselMusicBox-back.jpg\r\nhttp://www.genux.com/files-V2/img-8/pg-49294-ek1.jpg\r\nhttp://carouselstore.com/images/MCMiniMusicalCarouselS.jpg\r\nhttp://www.sfmusicbox.com/images/001/122/200600018915_hs.jpg\r\nhttp://www.veilingmaastricht.nl/veilingen/dec2005/fotos/laag/038.jpg\r\nhttp://www.rollerorgans.com/gallery/New_American_Musical_Box_.jpg\r\nhttp://www.arnovanderheijden.nl/winkel/plaatje_symphonion-6.jpg\r\nhttp://static.flickr.com/51/133555004_ab8632a9ab.jpg\r\nhttp://i1.ebayimg.com/02/i/000/d0/f2/1697_0.JPG\r\nhttp://www.pixelydixel.com/img/20050923pyd02.jpg\r\nhttp://www.hupfeld.co.uk/images/luxurymusicboxes/luxurymusicboxes_mb3101_open.jpg\r\nhttp://www.beyondthetree.com/smmangel_music_box.jpg\r\nhttp://home.hetnet.nl/~adrizwaan/muziekdoos__elfje.jpg\r\nhttp://www.treasuresworldwide.com/product_images/2_IT62MUSLYRE.jpg\r\nhttp://www.kingsrivergifts.com/cr182sm.jpg\r\nhttp://farm3.static.flickr.com/2354/1577971639_2b6ad26676.jpg\r\nhttp://www.beyondthetree.com/sawheart.jpg\r\nhttp://images.oneofakindantiques.com/1688_antique_music_box_B.jpg\r\nhttp://www.stradosales.nl/afbeeldingen/afb%20goederen/Fryslan/muziekdoos-.jpg\r\nhttp://www.speeldozen.com/contents/media/t_F16%20Muziekd%20Engel%20III.JPG\r\nhttp://www.muziekdoos.com/contents/media/t_13092.jpg\r\nhttp://www.mbsgb.org.uk/gallery/drum_bells.jpg\r\nhttp://farm3.static.flickr.com/2038/2062767506_fc9034c538.jpg\r\nhttp://www.mbsgb.org.uk/images/pic1.jpg\r\nhttp://www.ma-boite-a-musique.com/content/product_214995b.jpg\r\nhttp://www.morrismuseum.org/static/images/content/box2.jpg\r\nhttp://mailjust4me.com/crafts/ballerinamusicalbox.jpg\r\nhttp://www.thefurniture.com/store/images/CR/bk312.jpg\r\nhttp://www.cotps.com/i220a1.jpg\r\nhttp://www.regalidacomo.com/products_pictures/papa%20orso%20pm.jpg\r\nhttp://farm3.static.flickr.com/2392/2164125711_6ef29e5b34.jpg\r\nhttp://bp2.blogger.com/_R68tvgRPLSU/R6XpLn_BIKI/AAAAAAAAALg/HKPKQ2pitns/s320/music_box_open_b.jpg\r\nhttp://www.diabolo.es/shop/images/101.jpg\r\nhttp://www.magicalmusicboxes.com/images/luxurymusicboxes/luxurymusicboxes_mb5301_open.jpg\r\nhttp://www.jewelryboxemporium.com/Italian%20Music%20Jewelry%20Box%20Instrument%20Floral%20L%2010.5.jpg\r\nhttp://www.mygrannysatticantiques.com/assets/images/animated_train_music_box.jpg\r\nhttp:// ...

# %%
electric = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n03279153")   
print(electric.content)
electric_soup = BeautifulSoup(electric.content, 'html.parser')
# Out:
# b'http://www.lamusic.ca/pics/13035.jpg\r\nhttp://farm3.static.flickr.com/2227/1510006782_8893c452e9.jpg\r\nhttp://farm4.static.flickr.com/3093/2567134839_70dd7dc6cd.jpg\r\nhttp://www.obsolete.com/120_years/machines/multimonica/multimonica.JPG\r\nhttp://www.chinawholesalegift.com/pic/Toy-Gifts/Keyboard-Musical-Instument/ELECTRONIC-KEYBOARD-2151349631.jpg\r\nhttp://salestores.com/stores/images/images_747/SA75.jpg\r\nhttp://www.thesecretsout.net/productPics/CA11000388M_Keyboard.jpg\r\nhttp://www.casiojv.com/emi/standard_head.jpg\r\nhttp://farm3.static.flickr.com/2386/1510044910_30b6bcaecf.jpg\r\nhttp://www.eocs.org.uk/eocs1.jpg\r\nhttp://images.indiaplaza.in/Stores/PCStore/Images/Lpsr-e203.jpg\r\nhttp://www.yonies.com/images/productImages/pid2331.jpg\r\nhttp://i4.ebayimg.com/05/i/000/ee/04/873d_12.JPG\r\nhttp://farm3.static.flickr.com/2253/2043964721_303752ae8d.jpg\r\nhttp://www.casio-europe.com/euro/images/corporate/detail/1980.jpg\r\nhttp://www.sharmamusicals.com/ProductImages/Har-07%20Big-Size.jpg\r\nhttp://farm1.static.flickr.com/159/438973675_4122d13327.jpg\r\nhttp://www.sharmamusicals.com/Productimages/Thumbnail(160x130).jpg\r\nhttp://www.yamahasynth.com/products/mw/images/features_fig04.jpg\r\nhttp://thumbs.dreamstime.com/thumb_31/11330900205JX8w7.jpg\r\nhttp://static.flickr.com/237/461896479_403a09e7d3.jpg\r\nhttp://www.musical-instrumentsuk.co.uk/thumb.cgi?image=00459.jpg&amp;ref=Fender+Deluxe+PowerHouse+Strat+Caramel+Met&amp;save=\r\nhttp://www.agcomp.cz/KLAVESY_soubory/image002.jpg\r\nhttp://www.infectionmusic.com/instruments/images/FrontPageImageAug07.jpg\r\nhttp://www.gizmodo.com/archives/images/roland_fr7.jpg\r\nhttp://media.zzounds.com/media/brand,zzounds/p19383h-d7ec2139b2e0a19557c0f1dde36e33f0.jpg\r\nhttp://www.yamahasynth.com/products/motifxs/images/index_photo.jpg\r\nhttp://www.arts.arizona.edu/accordion/Images/SoltanMS40.gif\r\nhttp://www.record-producer.com/i/midi-keyboard2.jpg\r\nhttp://i3.iofferphoto.com/img/item/515/054/06/o_101_9950.jpg\r\nhttp://musicrx.us/images/Rhodes.jpg\r\nhttp://www.afternotemusic.com/img/sm_electronic.jpg\r\nhttp://www.obsolete.com/120_years/machines/serge/serge_modular1979.jpg\r\nhttp://www.carioelectronics.com/images/300/496ctk.jpg\r\nhttp://www.musical-instrumentsuk.co.uk/thumb.cgi?image=00039.jpg&amp;ref=Yamaha+BB415+Bass+Guitar&amp;save=\r\nhttp://remixmag.com/gear/reviews/802native_instruments.gif\r\nhttp://farm1.static.flickr.com/234/452690701_a2987e8b28.jpg\r\nhttp://www.pianotrends.com/images/GEM_wk2.jpg\r\nhttp://images.amazon.com/images/P/B00002JV63.01.MZZZZZZZ.jpg\r\nhttp://www.mustime.com/products/E-piano/image/big-yamaha-p60.jpg\r\nhttp://ruskeys.net/base/img/maestro1.jpg\r\nhttp://glitchdesk.com/cb/020/cz-230s-2.jpg\r\nhttp://www.casio-intl.com/emi/piano/al100r/images/top_img01.jpg\r\nhttp://images.amazon.com/images/P/B00005Q5J2.01.TZZZZZZZ.jpg\r\nhttp://retrothing.typepad.com/photos/uncategorized/2008/01/20/moogvoyageros.jpg\r\nhttp://stars.luneng.com/image20010518/16243.jpg\r\nhttp://edge2.dealsdirect.net/images/products/1444/1/product1_1444.jpg\r\nhttp://www.btauction.com.au/11photo/DD-50_2.jpg\r\nhttp://static.flickr.com/177/438958660_9f0907f115.jpg\r\nhttp://images.indiaplaza.in/Stores/PCStore/Images/LPSR-2100.jpg\r\nhttp://www.musicaltoysplus.com/images/WTPR_L_edit.jpg\r\nhttp://www.asianproducts.com/images/psimage/3/P11328216858587502s.jpg\r\nhttp://www.indiamart.com/skyking/pcat-gifs/products-small/korg.jpg\r\nhttp://www.guitarmine.com/products/DSC01531.jpg\r\nhttp://farm1.static.flickr.com/170/438973673_edf1f25db1.jpg\r\nhttp://www.jlpnetworksstore.com/catalog/KB4911RPL.jpg\r\nhttp://www.synthmania.com/Keyboards/Casio/MT-500/Images/MT-500.jpg\r\nhttp://www.spectrum.ieee.org/careers/careersarchive/people/feb04/0204frejob01.jpg\r\nhttp://www.cantonmusic.com/graphic2.jpg\r\nhttp://glitchdesk.com/cb/010/sk-1-keytar.jpg\r\nhttp://www.yamahamusic.com.au/products/musicproduction/synths/images/mo.jpg\r\nhttp://www.casio-intl.com/emi/high_grade/images/wk8000/ph_wk800 ...

# %%
stringed_str_soup=str(stringed_soup)
type(stringed_str_soup)
stringed_split_urls=stringed_str_soup.split('\r\n')
print(len(stringed_split_urls))
# Out:
# 2029

# %%
percussion_str_soup=str(percussion_soup)
type(percussion_str_soup)
percussion_split_urls=percussion_str_soup.split('\r\n')
print(len(percussion_split_urls))
# Out:
# 1274

# %%
wind_str_soup=str(wind_soup)
type(wind_str_soup)
wind_split_urls=wind_str_soup.split('\r\n')
print(len(wind_split_urls))
# Out:
# 1434

# %%
keyboard_str_soup=str(keyboard_soup)
type(keyboard_str_soup)
keyboard_split_urls=keyboard_str_soup.split('\r\n')
print(len(keyboard_split_urls))
# Out:
# 1214

# %%
bass_str_soup=str(bass_soup)
type(bass_str_soup)
bass_split_urls=bass_str_soup.split('\r\n')
print(len(bass_split_urls))
# Out:
# 1172

# %%
barrel_str_soup=str(barrel_soup)
type(barrel_str_soup)
barrel_split_urls=barrel_str_soup.split('\r\n')
print(len(barrel_split_urls))
# Out:
# 292

# %%
jews_str_soup=str(jews_soup)
type(jews_str_soup)
jews_split_urls=jews_str_soup.split('\r\n')
print(len(jews_split_urls))
# Out:
# 554

# %%
music_str_soup=str(music_soup)
type(music_str_soup)
music_split_urls=music_str_soup.split('\r\n')
print(len(music_split_urls))
# Out:
# 652

# %%
electric_str_soup=str(electric_soup)
type(electric_str_soup)
electric_split_urls=electric_str_soup.split('\r\n')
print(len(electric_split_urls))
# Out:
# 442

# %% [markdown]
# # **Preparing the data**

# %%
# !mkdir /content/instrument_train/ 
# !mkdir /content/instrument_test/ 

# !mkdir /content/instrument_train/stringed

# !mkdir /content/instrument_train/percussion 

# !mkdir /content/instrument_train/wind 

# !mkdir /content/instrument_train/keyboard 

# !mkdir /content/instrument_train/bass 

# !mkdir /content/instrument_train/barrel 

# !mkdir /content/instrument_train/jews 

# !mkdir /content/instrument_train/music 

# !mkdir /content/instrument_train/electric

# %%
img_rows, img_cols = 32, 32 
input_shape = (img_rows, img_cols, 3)

def url_to_image(url):
	resp = urllib.request.urlopen(url)
	image = np.asarray(bytearray(resp.read()), dtype="uint8")
	image = cv2.imdecode(image, cv2.IMREAD_COLOR)
 
	
	return image

n_of_training_images=150

# %%
for progress in range(n_of_training_images):
 
    if(progress%20==0):
        print(progress)
    if not stringed_split_urls[progress] == None:
      try:
        I = url_to_image(stringed_split_urls[progress])
        if (len(I.shape))==3: 
          save_path = '/content/instrument_train/stringed/stringed.'+str(progress)+'.jpg'
          cv2.imwrite(save_path,I)

      except:
        None

# %%
for progress in range(n_of_training_images):
 
    if(progress%20==0):
        print(progress)
    if not percussion_split_urls[progress] == None:
      try:
        I = url_to_image(percussion_split_urls[progress])
        if (len(I.shape))==3: 
          save_path = '/content/instrument_train/percussion/percussion.'+str(progress)+'.jpg'
          cv2.imwrite(save_path,I)

      except:
        None

# %%
for progress in range(n_of_training_images):
 
    if(progress%20==0):
        print(progress)
    if not wind_split_urls[progress] == None:
      try:
        I = url_to_image(wind_split_urls[progress])
        if (len(I.shape))==3: 
          save_path = '/content/instrument_train/wind/wind.'+str(progress)+'.jpg'
          cv2.imwrite(save_path,I)

      except:
        None

# %%
for progress in range(n_of_training_images):
 
    if(progress%20==0):
        print(progress)
    if not keyboard_split_urls[progress] == None:
      try:
        I = url_to_image(keyboar_split_urls[progress])
        if (len(I.shape))==3: 
          save_path = '/content/instrument_train/keyboard/keyboard.'+str(progress)+'.jpg'
          cv2.imwrite(save_path,I)

      except:
        None

# %%
for progress in range(n_of_training_images):
 
    if(progress%20==0):
        print(progress)
    if not bass_split_urls[progress] == None:
      try:
        I = url_to_image(bass_split_urls[progress])
        if (len(I.shape))==3: 
          save_path = '/content/instrument_train/bass/bass.'+str(progress)+'.jpg'
          cv2.imwrite(save_path,I)

      except:
        None

# %%
for progress in range(n_of_training_images):
 
    if(progress%20==0):
        print(progress)
    if not barrel_split_urls[progress] == None:
      try:
        I = url_to_image(barrel_split_urls[progress])
        if (len(I.shape))==3: 
          save_path = '/content/instrument_train/barrel/barrel.'+str(progress)+'.jpg'
          cv2.imwrite(save_path,I)

      except:
        None

# %%
for progress in range(n_of_training_images):
 
    if(progress%20==0):
        print(progress)
    if not jews_split_urls[progress] == None:
      try:
        I = url_to_image(jews_split_urls[progress])
        if (len(I.shape))==3: 
          save_path = '/content/instrument_train/jews/jews.'+str(progress)+'.jpg'
          cv2.imwrite(save_path,I)

      except:
        None

# %%
for progress in range(n_of_training_images):
 
    if(progress%20==0):
        print(progress)
    if not music_split_urls[progress] == None:
      try:
        I = url_to_image(music_split_urls[progress])
        if (len(I.shape))==3: 
          save_path = '/content/instrument_train/music/music.'+str(progress)+'.jpg'
          cv2.imwrite(save_path,I)

      except:
        None

# %%
for progress in range(n_of_training_images):
 
    if(progress%20==0):
        print(progress)
    if not electric_split_urls[progress] == None:
      try:
        I = url_to_image(electric_split_urls[progress])
        if (len(I.shape))==3: 
          save_path = '/content/instrument_train/electric/electric.'+str(progress)+'.jpg'
          cv2.imwrite(save_path,I)

      except:
        None

# %% [markdown]
# # 2.1) Making the functions to get the training and validation set from the Images

# %%
X=[]
Z=[]
IMG_SIZE=150
STRINGED_DIR='/content/instrument_train/stringed'
PERCUSSION_DIR='/content/instrument_train/percussion'
WIND_DIR='/content/instrument_train/wind'
KEYBOARD_DIR='/content/instrument_train/keyboard'
BASS_DIR='/content/instrument_train/bass'
BARREL_DIR='/content/instrument_train/barrel'
JEWS_DIR='/content/instrument_train/jews'
MUSIC_DIR='/content/instrument_train/music'
ELECTRIC_DIR='/content/instrument_train/electric'

# %%
def assign_label(img,instrument_type):
    return instrument_type

# %%
def make_train_data(instrument_type,DIR):
    for img in tqdm(os.listdir(DIR)):
        label=assign_label(img,instrument_type)
        path = os.path.join(DIR,img)
        img = cv2.imread(path,cv2.IMREAD_COLOR)
        img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))
        
        X.append(np.array(img))
        Z.append(str(label))

# %%
from tqdm import tqdm

# %%
make_train_data('Stringed',STRINGED_DIR)
print(len(X))

# %%
make_train_data('Percussion',PERCUSSION_DIR)
print(len(X))

# %%
make_train_data('Wind',WIND_DIR)
print(len(X))

# %%
make_train_data('Keyboard',KEYBOARD_DIR)
print(len(X))

# %%
make_train_data('Bass',BASS_DIR)
print(len(X))

# %%
make_train_data('Barrel',BARREL_DIR)
print(len(X))

# %%
make_train_data('Jews',JEWS_DIR)
print(len(X))

# %%
make_train_data('Music',MUSIC_DIR)
print(len(X))

# %%
make_train_data('Electric',ELECTRIC_DIR)
print(len(X))

# %% [markdown]
# # **Importing various modules**

# %%
# Ignore  the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# data visualisation and manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
 
#configure
# sets matplotlib to inline and displays graphs below the corressponding cell.
# %matplotlib inline  
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

#model selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

#preprocess.
from keras.preprocessing.image import ImageDataGenerator

#dl libraraies
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
from keras.utils import to_categorical

# specifically for cnn
from keras.layers import Dropout, Flatten,Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
 
import tensorflow as tf
import random as rn

# specifically for manipulating zipped images and getting numpy arrays of pixel values of images.
import cv2                  
import numpy as np  
from tqdm import tqdm
import os                   
from random import shuffle  
from zipfile import ZipFile
from PIL import Image

# %% [markdown]
# # 2.2 ) Label Encoding the Y array (i.e. stringed->0, percussion->1 etc...) & then One Hot Encoding

# %%
le=LabelEncoder()
Y=le.fit_transform(Z)
Y=to_categorical(Y,9)
X=np.array(X)
X=X/255

# %% [markdown]
# # 2.3) Splitting into Training and Validation Sets

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %% [markdown]
# # 2.4 ) Setting the Random Seeds

# %%
np.random.seed(42)
rn.seed(42)
tf.set_random_seed(42)

# %% [markdown]
# # **3 ) Modelling**

# %% [markdown]
# # 3.1 ) Building the ConvNet Model

# %%
# # modelling starts using a CNN.

model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',activation ='relu', input_shape = (150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
 

model.add(Conv2D(filters =96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(9, activation = "softmax"))

# %% [markdown]
# # 3.2 ) Using a LR Annealer

# %%
batch_size=9
epochs=20

from keras.callbacks import ReduceLROnPlateau
red_lr= ReduceLROnPlateau(monitor='val_acc',patience=3,verbose=1,factor=0.1)

# %% [markdown]
# # 3.3 ) Data Augmentation to prevent Overfitting

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %% [markdown]
# # 3.4 ) Compiling the Keras Model & Summary

# %%
model.compile(optimizer=Adam(lr=0.001),loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.summary()

# %% [markdown]
# # 3.5 ) Fitting on the Training set and making predcitons on the Validation set

# %%
History = model.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test,y_test), 
                              verbose = 1, steps_per_epoch=x_train.shape[0] // batch_size)
# model.fit(x_train,y_train,epochs=epochs,batch_size=batch_size,validation_data = (x_test,y_test))

# %% [markdown]
# # 4 ) Evaluating the Model Performance

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.plot(History.history['acc'])
plt.plot(History.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
# confusion matrix
import seaborn as sns
# Predict the values from the validation dataset
Y_pred = model.predict(x_test)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred,axis = 1) 
# Convert validation observations to one hot vectors
Y_true = np.argmax(y_test,axis = 1) 
# compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
# plot the confusion matrix
f,ax = plt.subplots(figsize=(8, 8))
sns.heatmap(confusion_mtx, annot=True, linewidths=0.01,cmap="Greens",linecolor="gray", fmt= '.1f',ax=ax)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
